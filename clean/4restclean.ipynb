# %%
import pandas as pd 
import numpy as np 

import os, sys
if os.path.abspath('../') not in sys.path:
    sys.path.insert(0, os.path.abspath('../'))

# %%
forest1 = pd.read_excel('../clean.ipynb/data/vietnamforestata.xlsx', sheet_name='Subnational 1 tree cover loss')

# %%
forest1
# Out:
#      country subnational1  threshold  area_ha  extent_2000_ha  extent_2010_ha  \
# 0    Vietnam     An Giang          0   352498          352498          352498
# 1    Vietnam     An Giang         10   352498           48217           46639
# 2    Vietnam     An Giang         15   352498           45309           39854
# 3    Vietnam     An Giang         20   352498           42334           39088
# 4    Vietnam     An Giang         25   352498           40944           36054
# ..       ...          ...        ...      ...             ...             ...
# 499  Vietnam    Đồng Tháp         20   338848           37846           55653
# 500  Vietnam    Đồng Tháp         25   338848           36299           51591
# 501  Vietnam    Đồng Tháp         30   338848           33680           46654
# 502  Vietnam    Đồng Tháp         50   338848           20605           30148
# 503  Vietnam    Đồng Tháp         75   338848            8161            9434
#
# ...

# %%
forest1 = forest1[['subnational1', 'tc_loss_ha_2015', 'tc_loss_ha_2016',
                    'tc_loss_ha_2017', 'tc_loss_ha_2018', 'tc_loss_ha_2019', 'tc_loss_ha_2020',
                    'tc_loss_ha_2021', 'tc_loss_ha_2022']]
## --> make prediction on 2022 dataset 
## so we need to get the econoic data from 2015 to 2022

# %%
# # group the dataset by province and average tc_loss_ha 
# forest1 = forest1.groupby('subnational1').sum().reset_index()
# forest1

# %%
forest1.columns
# Out:
# Index(['subnational1', 'tc_loss_ha_2015', 'tc_loss_ha_2016', 'tc_loss_ha_2017',
#        'tc_loss_ha_2018', 'tc_loss_ha_2019', 'tc_loss_ha_2020',
#        'tc_loss_ha_2021', 'tc_loss_ha_2022'],
#       dtype='object')

# %%
forest1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   subnational1     504 non-null    object
#  1   tc_loss_ha_2015  504 non-null    int64
#  2   tc_loss_ha_2016  504 non-null    int64
#  3   tc_loss_ha_2017  504 non-null    int64
#  4   tc_loss_ha_2018  504 non-null    int64
#  5   tc_loss_ha_2019  504 non-null    int64
#  6   tc_loss_ha_2020  504 non-null    int64
#  7   tc_loss_ha_2021  504 non-null    int64
#  8   tc_loss_ha_2022  504 non-null    int64
# dtypes: int64(8), object(1)
# memory usage: 35.6+ KB

# %%
selected_columns = forest1.loc[:, 'tc_loss_ha_2015':'tc_loss_ha_2022']
forest1['2001_2022_avg_tc_loss'] = selected_columns.mean(axis=1)
forest1
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18064\937719136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forest1['2001_2022_avg_tc_loss'] = selected_columns.mean(axis=1)
#     subnational1  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 0       An Giang               70              264              253
# 1       An Giang               31              129              130
# 2       An Giang               30              120              121
# 3       An Giang               28              113              117
# 4       An Giang               27              106              109
# ..           ...              ...              ...              ...
# 499    Đồng Tháp               54              196               97
# ...

# %%
#describe transpose the data
forest1.describe().T
# Out:
#                        count         mean          std  min     25%       50%  \
# tc_loss_ha_2015        504.0  3494.373016  4981.282052  0.0   56.75  1584.000
# tc_loss_ha_2016        504.0  5642.601190  6974.846487  0.0  173.00  2769.500
# tc_loss_ha_2017        504.0  4630.099206  5471.987529  0.0  134.75  2762.000
# tc_loss_ha_2018        504.0  3645.500000  4396.386792  0.0   62.50  1941.000
# tc_loss_ha_2019        504.0  3530.878968  4384.914474  0.0   55.50  1919.000
# tc_loss_ha_2020        504.0  3373.626984  4161.705478  0.0   62.75  1802.000
# tc_loss_ha_2021        504.0  3197.208333  4204.973105  0.0   34.00  1513.500
# tc_loss_ha_2022        504.0  2747.418651  3691.690857  0.0   36.50  1480.500
# 2001_2022_avg_tc_loss  504.0  3782.713294  4562.230357  0.0   87.25  1978.125
#
#                               75%        max
# tc_loss_ha_2015        5537.25000  39946.000
# tc_loss_ha_2016        8638.50000  44177.000
# tc_loss_ha_2017        8125.75000  34677.000
# ...

# %%
demtinh = forest1['subnational1'].value_counts()

# %%
forest1.head()
# Out:
#   subnational1  tc_loss_ha_2015  tc_loss_ha_2016  tc_loss_ha_2017  \
# 0     An Giang               70              264              253
# 1     An Giang               31              129              130
# 2     An Giang               30              120              121
# 3     An Giang               28              113              117
# 4     An Giang               27              106              109
#
#    tc_loss_ha_2018  tc_loss_ha_2019  tc_loss_ha_2020  tc_loss_ha_2021  \
# 0              130               45               16               55
# 1               77               24                6               20
# 2               74               23                6               19
# 3               71               22                6               18
# 4               68               21                5               17
#
#    tc_loss_ha_2022  2001_2022_avg_tc_loss
# 0               78                113.875
# 1               34                 56.375
# ...

# %%
forest1.describe().T
# Out:
#                        count         mean          std  min     25%       50%  \
# tc_loss_ha_2015        504.0  3494.373016  4981.282052  0.0   56.75  1584.000
# tc_loss_ha_2016        504.0  5642.601190  6974.846487  0.0  173.00  2769.500
# tc_loss_ha_2017        504.0  4630.099206  5471.987529  0.0  134.75  2762.000
# tc_loss_ha_2018        504.0  3645.500000  4396.386792  0.0   62.50  1941.000
# tc_loss_ha_2019        504.0  3530.878968  4384.914474  0.0   55.50  1919.000
# tc_loss_ha_2020        504.0  3373.626984  4161.705478  0.0   62.75  1802.000
# tc_loss_ha_2021        504.0  3197.208333  4204.973105  0.0   34.00  1513.500
# tc_loss_ha_2022        504.0  2747.418651  3691.690857  0.0   36.50  1480.500
# 2001_2022_avg_tc_loss  504.0  3782.713294  4562.230357  0.0   87.25  1978.125
#
#                               75%        max
# tc_loss_ha_2015        5537.25000  39946.000
# tc_loss_ha_2016        8638.50000  44177.000
# tc_loss_ha_2017        8125.75000  34677.000
# ...

# %%
# group the dataset by province and total tc_loss_ha
forest1 = forest1.groupby('subnational1').sum().reset_index()

# %%
# extract the subnational1 column
provinces = forest1['subnational1']
# save the column to excel 
provinces.to_excel('provinces.xlsx', index=False)
