# %% [markdown]
# ### d m dataset ham~L

# %%
import pandas as pd
import os
import sys

if os.path.abspath('../') not in sys.path:
    sys.path.insert(0, os.path.abspath('../'))

# %%
Vie_weather = pd.read_csv('../data/environment.raw_openweather.csv')
Vie_weather
# Out:
#                           _id    temp  temp_min     sunrise  \
# 0    659e617af63ecd73f81c104c  304.11    304.11  1704842263
# 1    659e617af63ecd73f81c104d  301.75    301.75  1704842135
# 2    659e617af63ecd73f81c104e  303.04    303.04  1704842362
# 3    659e617af63ecd73f81c104f  303.11    303.11  1704842106
# 4    659e617af63ecd73f81c1050  305.12    305.12  1704842319
# ..                        ...     ...       ...         ...
# 632  65a02a555903ce0f56e713bb  291.10    291.10  1705016866
# 633  65a02ab05903ce0f56e713bc  290.15    290.15  1705016149
# 634  65a02b0a5903ce0f56e713bd  291.51    291.51  1705016247
# 635  65a02b645903ce0f56e713be  290.12    290.12  1705016278
# 636  65a02bbe5903ce0f56e713bf  290.12    290.12  1705016239
#
#              report_time      sunset       description  humidity  \
# 0    2024-01-10 09:13:35  1704884095   overcast clouds        53
# 1    2024-01-10 09:15:06  1704883947   overcast clouds        64
# 2    2024-01-10 09:16:36  1704884028   overcast clouds        66
# 3    2024-01-10 09:18:06  1704883854   overcast clouds        56
# 4    2024-01-10 09:19:37  1704883911   overcast clouds        52
# ..                   ...         ...               ...       ...
# 632  2024-01-11 17:50:13  1705056212  scattered clouds        98
# 633  2024-01-11 17:51:44  1705055573   overcast clouds        92
# 634  2024-01-11 17:53:14  1705055717   overcast clouds        97
# 635  2024-01-11 17:54:44  1705055641   overcast clouds        94
# 636  2024-01-11 17:56:14  1705055600   overcast clouds        93
#
#           location  pressure  feels_like  temp_max  wind
# 0           Ca Mau      1008      306.31    304.11  5.06
# 1         Bac Lieu      1008      304.09    301.75  7.07
# 2         Rach Gia      1008      307.01    303.04  2.05
# 3        Soc Trang      1008      305.15    303.11  5.68
# 4       Long Xuyen      1007      307.95    305.12  1.51
# ..             ...       ...         ...       ...   ...
# 632  Dien Bien Phu      1014      291.51    291.10  1.50
# 633         Ha Noi      1017      290.31    290.15  2.18
# 634       Hoa Binh      1017      291.93    291.51  0.88
# 635       Viet Tri      1017      290.33    290.12  1.10
# 636       Vinh Yen      1017      290.30    290.12  1.39
#
# [637 rows x 13 columns]

# %%
Vie_weather.columns
# Out:
# Index(['_id', 'temp', 'temp_min', 'sunrise', 'report_time', 'sunset',
#        'description', 'humidity', 'pressure', 'feels_like', 'temp_max', 'wind',
#        'province'],
#       dtype='object')

# %%
# count unique values in location columns 
locations = Vie_weather['location'].value_counts()
print(locations.index)
# Out:
# Index(['Ca Mau', 'Tuy Hoa', 'Turan', 'Quang Ngai', 'Hoi An', 'Bac Lieu',
#        'Quang Tri', 'Kwang Binh', 'Ha Tinh', 'Vinh', 'Thanh Hoa', 'Ninh Binh',
#        'Nam Dinh', 'Thai Binh', 'Phu Ly', 'Hung Yen', 'Hai Duong', 'Haiphong',
#        'Ha Long', 'Lang Son', 'Cao Bang', 'Ha Giang', 'Lao Cai', 'Quy Nhon',
#        'Hue', 'Kon Tum', 'Phan Thiet', 'Pleiku', 'Loc Ninh', 'Bien Hoa',
#        'Vung Tau', 'Phu Khuong', 'Da Lat', 'Buon Ma Thuot',
#        'Phan Rang-Thap Cham', 'Nha Trang', 'Soc Trang', 'Vinh Yen', 'Viet Tri',
#        'Hoa Binh', 'Ha Noi', 'Dien Bien Phu', 'Son La', 'Lai Chau', 'Rach Gia',
#        'Vinh Long', 'Long Xuyen', 'Can Tho', 'Cao Lanh', 'Ben Tre', 'Tra Vinh',
#        'My Tho', 'Tan An', 'Ho Chi Minh City', 'Thu Dau Mot', 'Bac Giang',
#        'Bac Ninh', 'Yen Bai', 'Tuyen Quang', 'Thai Nguyen', 'Bac Kan'],
#       dtype='object', name='location')

# %% [markdown]
# ### Tan An --> Long An

# %%
city_province_mapping = {
    'Lang Son': 'Lang Son',
    'Hue': 'Thua Thien - Hue',
    'Kon Tum': 'Kon Tum',
    'Kwang Binh': 'Quang Binh',
    'Lao Cai': 'Lao Cai',
    'Loc Ninh': 'Binh Phuoc',
    'Nam Dinh': 'Nam Dinh',
    'Nha Trang': 'Khanh Hoa',
    'Ninh Binh': 'Ninh Binh',
    'Phan Rang-Thap Cham': 'Ninh Thuan',
    'Phan Thiet': 'Binh Thuan',
    'Phu Khuong': 'Binh Duong',
    'Phu Ly': 'Ha Nam',
    'Pleiku': 'Gia Lai',
    'Quang Ngai': 'Quang Ngai',
    'Quang Tri': 'Quang Tri',
    'Quy Nhon': 'Binh Dinh',
    'Thai Binh': 'Thai Binh',
    'Thanh Hoa': 'Thanh Hoa',
    'Turan': 'Hanoi',
    'Tuy Hoa': 'Phu Yen',
    'Hung Yen': 'Hung Yen',
    'Vinh': 'Nghe An',
    'Hoi An': 'Quang Nam',
    'Ha Long': 'Quang Ninh',
    'Bac Lieu': 'Bac Lieu',
    'Vung Tau': 'Ba Ria-Vung Tau',
    'Bien Hoa': 'Dong Nai',
    'Buon Ma Thuot': 'Dak Lak',
    'Ca Mau': 'Ca Mau',
    'Da Lat': 'Lam Dong',
    'Ha Giang': 'Ha Giang',
    'Cao Bang': 'Cao Bang',
    'Hai Duong': 'Hai Duong',
    'Haiphong': 'Hai Phong',
    'Ha Tinh': 'Ha Tinh',
    'Ha Noi': 'Hanoi',
    'Tan An': 'Long An',
    'Ho Chi Minh City': 'Ho Chi Minh city',
    'Lai Chau': 'Lai Chau',
    'Tra Vinh': 'Tra Vinh',
    'Thu Dau Mot': 'Binh Duong',
    'Ben Tre': 'Ben Tre',
    'Vinh Long': 'Vinh Long',
    'Viet Tri': 'Phu Tho',
    'Soc Trang': 'Soc Trang',
    'Son La': 'Son La',
    'Rach Gia': 'Kien Giang',
    'Can Tho': 'Can Tho',
    'Hoa Binh': 'Hoa Binh',
    'Cao Lanh': 'Dong Thap',
    'Vinh Yen': 'Vinh Phuc',
    'Dien Bien Phu': 'Dien Bien',
    'My Tho': 'Tien Giang',
    'Long Xuyen': 'An Giang',
    'Bac Giang': 'Bac Giang',
    'Bac Ninh': 'Bac Ninh',
    'Yen Bai': 'Yen Bai',
    'Tuyen Quang': 'Tuyen Quang',
    'Thai Nguyen': 'Thai Nguyen',
    'Bac Kan': 'Bac Kan'
}

# Replace the city names with corresponding provinces
Vie_weather['province'] = Vie_weather['location'].replace(city_province_mapping)
# drop location column 
Vie_weather.drop(columns=['location'], inplace=True)

# %%
# sort by location 
Vie_weather = Vie_weather.sort_values(by='province')
Vie_weather
# Out:
#                           _id    temp  temp_min     sunrise  \
# 403  659fd98d5903ce0f56e712d6  301.12    301.12  1704928736
# 220  659f98f45903ce0f56e7121f  305.12    305.12  1704928736
# 586  65a01a1d5903ce0f56e7138d  298.12    298.12  1704928736
# 464  659fef145903ce0f56e71313  300.12    300.12  1704928736
# 281  659fae7b5903ce0f56e7125c  305.12    305.12  1704928736
# ..                        ...     ...       ...         ...
# 105  659ebdb9f1049a28ecb2ba9a  291.47    291.47  1704843642
# 517  65a001c75903ce0f56e71348  291.07    291.07  1704930050
# 334  659fc12f5903ce0f56e71291  291.41    291.41  1704930050
# 578  65a0174a5903ce0f56e71385  291.02    291.02  1704930050
# 456  659fec425903ce0f56e7130b  291.19    291.19  1704930050
#
#              report_time      sunset       description  humidity  pressure  \
# 403  2024-01-11 12:05:32  1704970342  scattered clouds        59      1009
# 220  2024-01-11 07:29:55  1704970342  scattered clouds        49      1009
# 586  2024-01-11 16:41:01  1704970342   overcast clouds        84      1012
# 464  2024-01-11 13:37:24  1704970342   overcast clouds        74      1012
# 281  2024-01-11 09:01:47  1704970342  scattered clouds        47      1008
# ..                   ...         ...               ...       ...       ...
# 105  2024-01-10 15:54:33  1704882852   overcast clouds        94      1017
# 517  2024-01-11 14:57:11  1704969292   overcast clouds        97      1018
# 334  2024-01-11 10:21:35  1704969292   overcast clouds        96      1016
# 578  2024-01-11 16:28:58  1704969292   overcast clouds        97      1017
# 456  2024-01-11 13:25:22  1704969292   overcast clouds        96      1018
#
#      feels_like  temp_max  wind  province
# 403      302.45    301.12  1.95  An Giang
# 220      307.22    305.12  2.48  An Giang
# 586      298.87    298.12  3.02  An Giang
# 464      302.29    300.12  4.09  An Giang
# 281      306.77    305.12  1.68  An Giang
# ..          ...       ...   ...       ...
# 105      291.81    291.47  0.93   Yen Bai
# 517      291.45    291.07  0.90   Yen Bai
# 334      291.80    291.41  0.98   Yen Bai
# 578      291.40    291.02  0.72   Yen Bai
# 456      291.56    291.19  0.84   Yen Bai
#
# [637 rows x 13 columns]

# %%
provinces = Vie_weather['province'].value_counts().sort_index()
print(provinces.index)
# print the values of each provinces 
print(provinces.values)
# Out:
# Index(['An Giang', 'Ba Ria-Vung Tau', 'Bac Giang', 'Bac Kan', 'Bac Lieu',
#        'Bac Ninh', 'Ben Tre', 'Binh Dinh', 'Binh Duong', 'Binh Phuoc',
#        'Binh Thuan', 'Ca Mau', 'Can Tho', 'Cao Bang', 'Dak Lak', 'Dien Bien',
#        'Dong Nai', 'Dong Thap', 'Gia Lai', 'Ha Giang', 'Ha Nam', 'Ha Tinh',
#        'Hai Duong', 'Hai Phong', 'Hanoi', 'Ho Chi Minh city', 'Hoa Binh',
#        'Hung Yen', 'Khanh Hoa', 'Kien Giang', 'Kon Tum', 'Lai Chau',
#        'Lam Dong', 'Lang Son', 'Lao Cai', 'Long An', 'Nam Dinh', 'Nghe An',
#        'Ninh Binh', 'Ninh Thuan', 'Phu Tho', 'Phu Yen', 'Quang Binh',
#        'Quang Nam', 'Quang Ngai', 'Quang Ninh', 'Quang Tri', 'Soc Trang',
#        'Son La', 'Thai Binh', 'Thai Nguyen', 'Thanh Hoa', 'Thua Thien - Hue',
#        'Tien Giang', 'Tra Vinh', 'Tuyen Quang', 'Vinh Long', 'Vinh Phuc',
#        'Yen Bai'],
#       dtype='object', name='province')
# [10 11  9  8 11  9 10 11 21 11 11 11 10 11 11 10 11 10 11 11 11 11 11 11
#  21 10 10 11 11 10 11 10 11 11 11 10 11 11 11 11 10 11 11 11 11 11 11 10
#  10 11  8 11 11 10 10  8 10 10  9]

# %% [markdown]
# ## missing provinces: Dak Nong and Da Nang
# --> fill the Da Nang data by Quang Nam and
# ####
# --> Dak Nong by Lam Dong (Since they are neighbors--> same weather)
